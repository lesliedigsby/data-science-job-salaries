# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('ds_salaries.csv')
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
print(df.info())
print(df.describe())
print(df.isnull().sum())
print(df.nunique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB
# None
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# ...

# %%
df['experience_level'] = df['experience_level'].replace({
    'EN': 'Entry-Level',
    'MI': 'Mid-Level',
    'SE': 'Senior-Level',
    'EX': 'Executive-Level'
})
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020        Mid-Level              FT              Data Scientist
# 1       2020     Senior-Level              FT  Machine Learning Scientist
# 2       2020     Senior-Level              FT           Big Data Engineer
# 3       2020        Mid-Level              FT        Product Data Analyst
# 4       2020     Senior-Level              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# ...

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10, 6))
sns.histplot(df['salary_in_usd'], bins=30, kde=True, palette='crest')
plt.title('Distribution of Salaries in USD')
plt.xlabel('Salary in USD')
plt.ylabel('Frequency')
plt.show()
# Out:
# /var/folders/8n/jhbvq54x0jq35s2l1pyvd7nm0000gn/T/ipykernel_47559/2033408741.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['salary_in_usd'], bins=30, kde=True, palette='crest')

# %% [markdown]
# We can see that the majority of the salary data is around the $100,000 mark.

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10, 6))
sns.boxplot(x='experience_level', y='salary_in_usd', data=df, palette='crest')
plt.title('Salary Distribution by Experience Level')
plt.xlabel('Experience Level')
plt.ylabel('Salary in USD')
plt.show()
# Out:
# /var/folders/8n/jhbvq54x0jq35s2l1pyvd7nm0000gn/T/ipykernel_47559/2658819855.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='experience_level', y='salary_in_usd', data=df, palette='crest')

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10, 6))
sns.boxplot(x='remote_ratio', y='salary_in_usd', data=df, palette='viridis')
plt.title('Salary Distribution by Remote Work Ratio')
plt.xlabel('Remote Work Ratio')
plt.ylabel('Salary in USD')
plt.show()
# Out:
# /var/folders/8n/jhbvq54x0jq35s2l1pyvd7nm0000gn/T/ipykernel_47559/670395335.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='remote_ratio', y='salary_in_usd', data=df, palette='viridis')

# %%
df.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=False).head(10)
# Out:
# job_title
# Data Analytics Lead         405000.000000
# Principal Data Engineer     328333.333333
# Financial Data Analyst      275000.000000
# Principal Data Scientist    215242.428571
# Director of Data Science    195074.000000
# Data Architect              177873.909091
# Applied Data Scientist      175655.000000
# Analytics Engineer          175000.000000
# Data Specialist             165000.000000
# Head of Data                160162.600000
# Name: salary_in_usd, dtype: float64

# %% [markdown]
# Remote roles seem to offer higher salaries on average. Although there is overlap seen over all categories.

# %% [markdown]
# Is there a pay gap between data analysts and data scientists at the same experience level?

# %%
roles = ['Data Analyst', 'Data Scientist']
subset = df[df['job_title'].isin(roles)]

salary_comparison = (
    subset.groupby(['experience_level', 'job_title'])['salary_in_usd']
    .mean()
    .reset_index()
    .sort_values('experience_level')
)
print(salary_comparison)
# Out:
#   experience_level       job_title  salary_in_usd
# 0      Entry-Level    Data Analyst   53960.666667
# 1      Entry-Level  Data Scientist   55330.909091
# 2  Executive-Level    Data Analyst  120000.000000
# 3        Mid-Level    Data Analyst   71699.206897
# 4        Mid-Level  Data Scientist   82039.133333
# 5     Senior-Level    Data Analyst  111922.629630
# 6     Senior-Level  Data Scientist  152971.016393

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(8, 6))
sns.barplot(
    data=salary_comparison,
    x='experience_level',
    y='salary_in_usd',
    hue='job_title',
    palette='crest'
)
plt.title('Average Salary: Data Analyst vs Data Scientist by Experience Level')
plt.xlabel('Experience Level')
plt.ylabel('Average Salary in USD')
plt.legend(title='Job Title')
plt.show()

# %% [markdown]
# Upon analysis with the aid of some visualization, we can see that although at entry-level both roles earn similar salary. The gap widens with seniority.

# %%
gap = salary_comparison.pivot(index='experience_level', columns='job_title', values='salary_in_usd')
gap['percent_gap'] = ((gap['Data Scientist'] - gap['Data Analyst']) / gap['Data Analyst']) * 100
print(gap[['Data Analyst', 'Data Scientist', 'percent_gap']])
# Out:
# job_title          Data Analyst  Data Scientist  percent_gap
# experience_level
# Entry-Level        53960.666667    55330.909091     2.539336
# Executive-Level   120000.000000             NaN          NaN
# Mid-Level          71699.206897    82039.133333    14.421256
# Senior-Level      111922.629630   152971.016393    36.675681

# %% [markdown]
# By mid-level and senior stages, the difference in salary reaches about 37% higher for data scientists vs data analysts. While both roles benefit from experience, the additional skills required for data scientists (machine learning, statistical modeling) drive the higher compensation.

# %% [markdown]
# 🏁 Conclusion and Next Steps
#
# This analysis of the Data Science Job Salaries dataset provides clear evidence of how compensation in the field varies by role, experience level, company size, and work arrangement.
#
# Main takeaways:
# 	•	💼 Experience level is the strongest driver of salary growth — senior and executive roles earn several times more than entry-level positions.
# 	•	🌍 Geography and company size play major roles, with U.S.-based and large organizations offering higher median pay.
# 	•	🏠 Remote work is increasingly common and often associated with higher salaries, especially among senior professionals.
# 	•	🔍 Role comparison: Data Scientists consistently earn 14–37% more than Data Analysts at the same experience level, reflecting the premium placed on advanced technical and modeling skills.
#
# Overall, the data shows that specialization, technical depth, and continuous upskilling drive long-term earning potential in the data science career path.
#
# ⸻
#
# 🚀 Next Steps
# 	•	Modeling: Build a simple regression model to predict salary based on experience, company size, and remote ratio.
# 	•	Visualization: Create an interactive Streamlit dashboard so users can explore salary trends by role or country.
# 	•	Expansion: Integrate cost-of-living data to adjust salaries and uncover true global comparisons.
